# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('DATA/PT13.jpg')

# %%
plt.imshow(flat_chess)

# %%
found,corners=cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# True

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[103, 103, 103],
#         [ 92,  92,  92],
#         [ 94,  94,  94],
#         ...,
#         [ 93,  93,  93],
#         [ 97,  97,  97],
#         [ 99,  99,  99]],
#
#        [[ 32,  32,  32],
#         [ 27,  27,  27],
#         [ 34,  34,  34],
#         ...,
#         [ 77,  77,  77],
#         [ 65,  65,  65],
#         [ 36,  36,  36]],
#
#        [[ 33,  33,  33],
#         [ 29,  29,  29],
#         [ 35,  35,  35],
#         ...,
#         [220, 220, 220],
#         [170, 170, 170],
#         [ 46,  46,  46]],
#
#        ...,
#
#        [[ 58,  58,  58],
#         [192, 192, 192],
#         [238, 238, 238],
#         ...,
#         [ 23,  23,  23],
#         [ 24,  24,  24],
#         [ 29,  29,  29]],
#
#        [[ 28,  28,  28],
#         [ 85,  85,  85],
#         [ 91,  91,  91],
#         ...,
#         [ 25,  25,  25],
#         [ 26,  26,  26],
#         [ 29,  29,  29]],
#
#        [[ 84,  84,  84],
#         [ 87,  87,  87],
#         [ 72,  72,  72],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots = cv2.imread('DATA/PT14.jpg')
plt.imshow(dots)

# %%
found,corners=cv2.findCirclesGrid(dots,(6,7),cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
cv2.drawChessboardCorners(dots,(6,7),corners,found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(dots)

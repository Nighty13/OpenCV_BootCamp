# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
ls DATA
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 000D-E0F3
#
#  Directory of C:\Users\ALPHA\Desktop\OpenCV_py\DATA
#
# 12/05/2019  23:35    <DIR>          .
# 12/05/2019  23:35    <DIR>          ..
# 29/04/2019  01:57           720ÿ997 PT01.png
#                1 File(s)        720ÿ997 bytes
#                2 Dir(s)  59ÿ539ÿ390ÿ464 bytes free

# %%
img=cv2.cvtColor((cv2.imread('DATA/PT01.png')),cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray=cv2.imread('DATA/PT01.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img.shape
# Out:
# (1040, 780, 3)

# %%
#RGB
plt.imshow(img[:,:,0],cmap='gray')

# %%
img[:,:,0]=0

# %%
plt.imshow(img)
